# %%
import numpy as np

# %%
arr=np.array([1,2,3,4])
print(arr)
arr1=arr+3
print(arr1)
# Out:
# [1 2 3 4]
# [4 5 6 7]

# %%
arr1=np.array([1,2,3,4])
print(arr1)
arr2=np.array([[10],[20],[30],[40]])
print(arr2)
arr1+arr2
print(arr)
# Out:
# [1 2 3 4]
# [[10]
#  [20]
#  [30]
#  [40]]
# [1 2 3 4]

# %%
arr1=np.arange(1,9)
print(arr1)
arr2=np.arange(10,18).reshape(2,4)
print(arr2)
arr=arr1+arr2
print(arr)
# Out:
# [1 2 3 4 5 6 7 8]
# [[10 11 12 13]
#  [14 15 16 17]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       3 arr2=np.arange(10,18).reshape(2,4)
#       4 print(arr2)
# ----> 5 arr=arr1+arr2
#       6 print(arr)
#
# ValueError: operands could not be broadcast together with shapes (8,) (2,4)

# %%
arr1=np.arange(1,9)
print(arr1)
arr2=np.arange(10,18).reshape(8,1)
print(arr2)
arr=arr1+arr2
print(arr)
# Out:
# [1 2 3 4 5 6 7 8]
# [[10]
#  [11]
#  [12]
#  [13]
#  [14]
#  [15]
#  [16]
#  [17]]
# [[11 12 13 14 15 16 17 18]
#  [12 13 14 15 16 17 18 19]
#  [13 14 15 16 17 18 19 20]
#  [14 15 16 17 18 19 20 21]
#  [15 16 17 18 19 20 21 22]
#  [16 17 18 19 20 21 22 23]
#  [17 18 19 20 21 22 23 24]
#  [18 19 20 21 22 23 24 25]]

# %%
arr1=np.array([[10,20,30],[40,50,60]])
print(arr1)
arr2=np.array([2,2,2])
print(arr2)
arr=arr1+arr2
print(arr)
# Out:
# [[10 20 30]
#  [40 50 60]]
# [2 2 2]
# [[12 22 32]
#  [42 52 62]]

# %%
arr1=np.array([[10,20],[30,40],[50,60]])
print(arr1)
arr2=np.array([2,2,2])
print(arr2)
arr=arr1+arr2
print(arr)
# Out:
# [[10 20]
#  [30 40]
#  [50 60]]
# [2 2 2]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 arr2=np.array([2,2,2])
#       4 print(arr2)
# ----> 5 arr=arr1+arr2
#       6 print(arr)
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
#copy vs view
#copy
arr=no.array([1,2,3,4])
print(arr)
arr_co=arr.copy
print(arr_co)
arr_co[0]=100
print(arr_co)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #copy vs view
#       2 #copy
# ----> 3 arr=no.array([1,2,3,4])
#       4 print(arr)
#       5 arr_co=arr.copy
#
# NameError: name 'no' is not defined
