# %%
# list - collection of element
# it denoted by [] with csv
# ordered,indexed,mutable and heterogenous in nature.
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[10,20,30,"hello",10.5]
print(l)
print(type(l))
print(l[-2])   # indexed
l[0]=1000    # mutable
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5]
# <class 'list'>
# hello
# [1000, 20, 30, 'hello', 10.5]

# %%
# iteration
# direct iteration
l=[10,20,30,"hello",10.5]
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# hello
# 10.5

# %%
# indirect iteration
l=[10,20,30,"hello",10.5]
for i in range(len(l)):
    print(i,l[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 hello
# 4 10.5

# %%
# function 
# len()
# len(listobj)
l=[10,20,30,"hello",10.5]
print(len(l))
count=0
for i in l:
    count=count+1
print(count)
# Out:
# 5
# 5

# %%
# max()
# max(listobj)
l=[10,20,30,10.5]
print(max(l))
print(min(l))
# Out:
# 30
# 10

# %%
l=[10,20,30,10.5]
max_value=l[0]
for i in l:
    if i>max_value:
        max_value=i
print(max_value)
# Out:
# 30

# %%
l=[10,20,30,10.5]
min_value=l[0]
for i in l:
    if i < min_value:
        min_value=i
print(min_value)
# Out:
# 10

# %%
l=[10,20,30,40,50]
print(sum(l))
sum_list=0
count=0
for i in l:
    sum_list=sum_list+i
    count=count+1
print(sum_list)
print(count)
mean=sum_list/count
print(mean)
# Out:
# 150
# 150
# 5
# 30.0

# %%
# Methods
# add element to an existing list.
# Append()
# listobj.append(value/element)
# new element -- position -1
l=[10,20,30,"hello",40]
l.append(1000)
print(l)
# Out:
# [10, 20, 30, 'hello', 40, 1000]

# %%
l=[10,20,30,"hello",40]
l.append(10.5)
print(l)
# Out:
# [10, 20, 30, 'hello', 40, 10.5]

# %%
l=[10,20,30,"hello",40]
l.append("decode")
print(l)
# Out:
# [10, 20, 30, 'hello', 40, 'decode']

# %%
l=[10,20,30,"hello",40]
l.append([100,200,300,"decode"])
print(l)
# Out:
# [10, 20, 30, 'hello', 40, [100, 200, 300, 'decode']]

# %%
l=[10,20,30,"hello",40]
l.append([100,200,300,"decode"])
print(l)
print(l[5][3][-2])
# Out:
# [10, 20, 30, 'hello', 40, [100, 200, 300, 'decode']]
# d

# %%
#create one homogenous list with 4 elements. (add element at runtime)
l=[]
for i in range(4):
    n=int(input("enter any number: "))
    l.append(n)
print(l)
# Out:
# enter any number:  10
# enter any number:  20
# enter any number:  30
# enter any number:  40
# [10, 20, 30, 40]

# %%
l=[]
for i in range(1,10,2):
    l.append(i**3)
print(l)
# Out:
# [1, 27, 125, 343, 729]

# %%
l=[]
for i in range(6):
    n=int(input("enter any number: "))
    l.append(n*n)
print(l)
# Out:
# enter any number:  5
# enter any number:  2
# enter any number:  1
# enter any number:  6
# enter any number:  3
# enter any number:  4
# [25, 4, 1, 36, 9, 16]

# %%
l=[]
for i in range(0,8,2):
    l.append(chr(65+i))
print(l)
# Out:
# ['A', 'C', 'E', 'G']

# %%
# insert
# listobj.insert(position,value/element)
l=[10,20,"hello",300,10.5]
l.insert(2,"decode")
print(l)
# Out:
# [10, 20, 'decode', 'hello', 300, 10.5]

# %%
#extend
#listobj.extend(sequencetype)
l=[10,20,30,"hello",10.5]
l.extend(l)
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 10, 20, 30, 'hello', 10.5]

# %%
l=[10,20,30,"hello",10.5]
l.extend([100])
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 100]

# %%
l=[10,20,30,"hello",10.5]
l.extend("decode")
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 'd', 'e', 'c', 'o', 'd', 'e']

# %%
l=[10,20,30,"hello",10.5]
l.extend((100,200,300))
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 100, 200, 300]

# %%
#remove element from an existing list
#pop()
#listobj.pop([position])
#by default :-1
#always return element.
l=[10,20,30,"decode",10.5]
print(l.pop())
print(l)
# Out:
# 10.5
# [10, 20, 30, 'decode']

# %%
l=[10,20,30,"decode",10.5]
print(l.pop(3))
print(l)
# Out:
# decode
# [10, 20, 30, 10.5]

# %%
#del
#del listobj[position] 
l=[10,20,30,"decode",10.5]
del l[3]
print(l)
# Out:
# [10, 20, 30, 10.5]

# %%
#remove
#listobj.remove(value)
l=[10,20,30,40,"hello",10.5]
l.remove("hello")
print(l)
# Out:
# [10, 20, 30, 40, 10.5]

# %%
l=[10,20,30,40,10,"hello",10.5,10]
l.remove(10)
print(l)
# Out:
# [20, 30, 40, 10, 'hello', 10.5, 10]

# %%
#clear()
l=[10,20,30,40,10,"hello",10.5,10]
l.clear()
print(l)
# Out:
# []

# %%
l=[100,200,300,[1000,2000,"hello",["A","B"],10.5],"decode",117]
l1=["bpl","ind"]
for i in l1:
    l[3][3].append(i)
print(l)
# Out:
# [100, 200, 300, [1000, 2000, 'hello', ['A', 'B', 'bpl', 'ind'], 10.5], 'decode', 117]

# %%
l=[100,200,300,[1000,2000,"hello",["A","B"],10.5],"decode",117]
l1=["bpl","ind"]
l[3][3].extend(l1)
print(l)
# Out:
# [100, 200, 300, [1000, 2000, 'hello', ['A', 'B', 'bpl', 'ind'], 10.5], 'decode', 117]

# %%
l=[100,200,300,[1000,2000,"hello",["A","B"],10.5],"decode",117]
l1=["bpl","ind"]
for i in l1:
    l[3][3].insert(3,i)
print(l)
# Out:
# [100, 200, 300, [1000, 2000, 'hello', ['A', 'B', 'bpl', 'ind'], 10.5], 'decode', 117]

# %%
#count - no. of occurence of any element.
l=[10,20,30,40,"hello",10,10,20,30,10]
print(l.count(10))
# Out:
# 4

# %%
#index
#listobj.index(element,[start],[stop])
l=[10,20,30,40,"hello",10,10,20,30,10]
print(l.index(10))
print(l.index(10,1))
print(l.index(10,1,5))
# Out:
# 0
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       4 print(l.index(10))
#       5 print(l.index(10,1))
# ----> 6 print(l.index(10,1,5))
#
# ValueError: 10 is not in list

# %%
#sort
#listobj.sort([reverse=False])
l=[10,20,1,19]
l.sort()
print(l)
# Out:
# [1, 10, 19, 20]

# %%
l=[10,20,1,19]
l.sort(reverse=True)
print(l)
# Out:
# [20, 19, 10, 1]

# %%
l=[10,20,1,19]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]>l[j]:
            l[i],l[j]=l[j],l[i]
print(l)
# Out:
# [1, 10, 19, 20]

# %%
l=[1,11,6,7,2,8]
target=18
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]+l[j]==target:
            print([i,j])
# Out:
# [1, 3]

# %%
l=[(2,5),(1,3),(4,1),(3,6),(6,2),(5,4)]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i][-1]>l[j][-1]:
            l[i],l[j]=l[j],l[i]
print(l)
# Out:
# [(4, 1), (6, 2), (1, 3), (5, 4), (2, 5), (3, 6)]

# %%
l=[[30,70,60],[100,300,200,400],[70,60,80]]
j=[]
for i in l:
        i.sort()
        j.append(i[-2])
print(j)
# Out:
# [60, 300, 70]

# %%
l=[1,11,6,7,2,8]
target=18
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]+l[j]==target:
            print([i,j])
# Out:
# [1, 3]

# %%
l=[(2,5),(1,3),(4,1),(3,6),(6,2),(5,4)]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i][-1]>l[j][-1]:
            l[i],l[j]=l[j],l[i]
print(l)
# Out:
# [(4, 1), (6, 2), (1, 3), (5, 4), (2, 5), (3, 6)]

# %%
l=[[30,70,60],[100,300,200,400],[70,60,80]]
l1=[]
for i in l:
    for j in range(len(i)):
        for k in range(j+1,len(i)):
            if i[j]>i[k]:
                i[j],i[k]=i[k],i[j]
                l1.append(i[-2])
print(l1)
# Out:
# [60, 300, 70]

# %%
l1=[10,20,30,40,50]
l2=[100,200,300,400]
for i in range(len(l1)):
    print(l1[i],l2[i])
# Out:
# 10 100
# 20 200
# 30 300
# 40 400
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 l2=[100,200,300,400]
#       3 for i in range(len(l1)):
# ----> 4     print(l1[i],l2[i])
#
# IndexError: list index out of range

# %%
# zip()
l1=[10,20,30,40,50]
l2=[100,200,300,400,500,600,700]
for i,j in zip(l1,l2):
    print(i,j)
# Out:
# 10 100
# 20 200
# 30 300
# 40 400
# 50 500

# %%
l1=[5,1,3,7,4,2]
l2=[2,6,4,1,3,5]
# [25,1,81,7,64,32]
l=[]
for i,j in zip(l1,l2):
    l.append(i**j)
print(l)
print([i**j for i,j in zip(l1,l2)])
# Out:
# [25, 1, 81, 7, 64, 32]
# [25, 1, 81, 7, 64, 32]

# %%
#list Comprehension
l1=[5,2,3,1,6]
l=[]
for i in l1:
    l.append(i**2)
print(l)
print([i**2 for i in l1])
# Out:
# [25, 4, 9, 1, 36]
# [25, 4, 9, 1, 36]

# %%
l=[]
for i in range(0,8,2):
    l.append(chr(65+i))
print(l)
print([chr(65+i) for i in range(0,8,2)])
# Out:
# ['A', 'C', 'E', 'G']
# ['A', 'C', 'E', 'G']

# %%
l1=[5,1,4,6,2,3]
l2=[2,6,3,1,5,4]
l=[]
for i,j in zip(l1,l2):
    l.append(i**j)
print(l)
print([i**j for i,j in zip(l1,l2)])
# Out:
# [25, 1, 64, 6, 32, 81]
# [25, 1, 64, 6, 32, 81]

# %%
l=["madam","bhopal","aa","decode","Naman"]
rev=""
l1=[]
for i in l:
    if i==i[::-1]:
        l1.append(i)
print(l1)
print([i for i in l if i==i[::-1]])
# Out:
# ['madam', 'aa']
# ['madam', 'aa']

# %%
l=[10,72,17,19,31,25,64,32,3]
l1=[]
for i in l:
    if i%2!=0:
        l1.append(i)
print(l1)
print([i for i in l if i%2!=0])
# Out:
# [17, 19, 31, 25, 3]
# [17, 19, 31, 25, 3]
