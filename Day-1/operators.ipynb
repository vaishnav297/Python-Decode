# %% [markdown]
# #operators

# %% [markdown]
# ###arithmetic

# %%
a=10
0b=2
print("addition",a+b)
# Out:
# addition 12

# %%
#bitwise operator &- bitwise and operator
#|-- bitwise or operator
#^-- bitwise xor operator
#bin() returns binary of given integer object.
a=10
b=8
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
print()
print(bin(a|b))
print(a|b)
print()
print(bin(a^b))
print(a^b)
# Out:
# 0b1010
# 0b1000
# 0b1000
# 8
#
# 0b1010
# 10
#
# 0b10
# 2
